# %% [markdown]
# <h1><center>CSE391  Data Science</center></h1>
#
# <h1><center>Lecture 8</center></h1>
# <h1><center>Sept 10th ,2018 </center></h1>

# %% [markdown]
# # Jupyter notebook Tips of the day
# ## Colors:
#
# -Use this code to color a text: <font color=red>Text</font>
#
# ##  Indenting:
# -Use a greater than sign (>) and then a space, then type the text. Everything is indented until the next carriage return.

# %% [markdown]
# # Data Science Process
# ![Screen%20Shot%202018-09-10%20at%201.56.42%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%201.56.42%20PM%20%282%29.png)

# %% [markdown]
# # Creating array using np.matrix

# %%
a = np.matrix([1,2,3,4])
a.shape
# Out:
# (1, 4)

# %% [markdown]
# # Each vector has a magnitude and a direction
# - How to compute the magnitue of a vector
# ![3D-vector.png](attachment:3D-vector.png)

# %% [markdown]
# # How to compute the  magnitude of a K dimensioanl array?

# %% [markdown]
# $\Huge \Huge \overrightarrow{x} = [x_1, x_2,\ldots, x_K]$

# %% [markdown]
# # We compute the magnitude in the following

# %% [markdown]
# $\Huge \Huge |\overrightarrow{x}|  = \sqrt{x_1^2+x_2^2+ \ldots+x_K^2} $

# %% [markdown]
# $\Huge \displaystyle \sum_{i=1}^{i = K} x_i^2 = x_1^2+x_2^2+ \ldots+x_K^2$
#
# $\Huge \displaystyle \sqrt{\sum_{i=1}^{ K} x_i^2} =\sqrt{ x_1^2+x_2^2+ \ldots+x_K^2}$

# %% [markdown]
# # How to vectorize this operation

# %% [markdown]
# $\large \overrightarrow{x} = [x_1, x_2,\ldots, x_K]$
#
#
#
# $ \large \overrightarrow{x}^T =
# \begin{bmatrix}
#     x_1 \\
#     x_2\\
#     \ldots \\
#     x_K
# \end{bmatrix}$

# %% [markdown]
# $\Huge \Huge |\overrightarrow{x}| = \sqrt{\overrightarrow{x} .\overrightarrow{x}^T} $

# %% [markdown]
# # Using vectorized form

# %%
# %%time
vec_sum = a.dot(a.T)

print( 'the magnitude using vectorized operation = ', np.asscalar(np.sqrt(vec_sum)))
# Out:
# the magnitude using vectorized operation =  229.08513701242165
# CPU times: user 291 µs, sys: 227 µs, total: 518 µs
# Wall time: 332 µs

# %% [markdown]
# # Some Basic Concepts in Linear Algebra
#
# ## Norm of a vector
# ![Screen%20Shot%202018-09-10%20at%204.11.29%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.11.29%20PM%20%282%29.png)
#
# ## Vector inner and outer product
# ![Screen%20Shot%202018-09-10%20at%204.14.17%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.14.17%20PM%20%282%29.png)
#
# ## How to show matrix and vecors
# ![Screen%20Shot%202018-09-10%20at%204.17.44%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.17.44%20PM%20%282%29.png)
#
# ## Special Matrices
# ![Screen%20Shot%202018-09-10%20at%204.19.35%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.19.35%20PM%20%282%29.png)
#
# ## Transpose
# ![Screen%20Shot%202018-09-10%20at%204.20.41%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.20.41%20PM%20%282%29.png)
#
# ## Linear Independent vectors
# ![Screen%20Shot%202018-09-10%20at%204.22.19%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.22.19%20PM%20%282%29.png)
#
# ## Span of a Vector Space
# ![Screen%20Shot%202018-09-10%20at%204.24.33%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.24.33%20PM%20%282%29.png)
#
# ## Rank of Matrix
# ![Screen%20Shot%202018-09-10%20at%204.26.38%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.26.38%20PM%20%282%29.png)
#
# ## Inverse of a Matrix
# ![Screen%20Shot%202018-09-10%20at%204.27.43%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.27.43%20PM%20%282%29.png)
#
# ## Singular Value Decomposition (SVD)
# ![Screen%20Shot%202018-09-10%20at%204.30.00%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.30.00%20PM%20%282%29.png)

# %% [markdown]
# # Basic of Statistical Analysis for Multi-dimensional Data

# %% [markdown]
# # What is statistical analysis?
# - It’s the science of collecting, exploring and presenting large amounts of data to discover underlying patterns and trends. Statistics are applied every day – in research, industry and government – to become more scientific about decisions that need to be made

# %% [markdown]
# # Statistical Inference
# - Statistical inference consists in the use of statistics to draw conclusions about some unknown aspect of a population based on a random sample from that population.
# - Statistical inference is the use of probability theory to make inferences about a population from sample data.
# - In practice we cannot obtain data from every member of the population. Instead, we obtain data from a sample and use the results to make inferences about the population.
# SCR: source ref: ebook.html

# %% [markdown]
# # Basic definitions
#
# - Population - collection of all subjects or objects of interest (not necessarily people)
#
# - Sample - subset of the population used to make inferences about the characteristics of the population
#
# - Population parameter - numerical characteristic of a population, a fixed and usually unknown quantity. e.g. average weight, µ, of all 30 year old women in Australia,
#
#
#
# - Data - values measured or recorded on the sample.
#
# - Sample statistic - numerical characteristic of the sample data such as the mean, proportion or variance. It can be used to provide estimates of the corresponding population parameters.
# ![Screen%20Shot%202018-09-10%20at%201.08.39%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%201.08.39%20PM%20%282%29.png)

# %% [markdown]
# ![Screen%20Shot%202018-09-10%20at%201.10.45%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%201.10.45%20PM%20%282%29.png)

# %% [markdown]
# ##  Parameter vs Statistic
# ![Screen%20Shot%202018-09-10%20at%204.39.24%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.39.24%20PM%20%282%29.png)

# %% [markdown]
# ## Is the estimation the same or close the actual values?
# - If the sample is not representative of the population being studied, the sample statistic may be biased so you cannot use it to make valid inferences about the population parameter
# - To minimise bias the sample should be chosen by random sampling from a list of all individuals in the relevant population. This list is called the sampling frame. It is essential.

# %% [markdown]
# ![Screen%20Shot%202018-09-10%20at%201.16.11%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%201.16.11%20PM%20%282%29.png)

# %% [markdown]
# #  Bias and Variance in Statistical Inference

# %% [markdown]
# # # Conceptual Definition
# - Error due to Bias: The error due to bias is taken as the difference between the expected (or average) prediction of our model and the correct value which we are trying to predict. Of course you only have one model so talking about expected or average prediction values might seem a little strange. However, imagine you could repeat the whole model building process more than once: each time you gather new data and run a new analysis creating a new model. Due to randomness in the underlying data sets, the resulting models will have a range of predictions. Bias measures how far off in general these models' predictions are from the correct value.
# - Error due to Variance: The error due to variance is taken as the variability of a model prediction for a given data point. Again, imagine you can repeat the entire model building process multiple times. The variance is how much the predictions for a given point vary between different realizations of the model.
#
# SRC : Scott Fortmann-Roe

# %% [markdown]
# ![Screen%20Shot%202018-09-10%20at%201.28.05%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%201.28.05%20PM%20%282%29.png)

# %% [markdown]
# # Probability Distribution
#
# - is a mathematical function that provides the probabilities of occurrence of different possible outcomes in an experiment.
# - There are many different types of probability distributions in statistics including:
#
# - Basic probability distributions which can be shown on a probability distribution table.
#
# - Binomial distributions, which have “Successes” and “Failures.”
# - Normal distributions, sometimes called a Bell Curve.
#
# ### Some popular probability distribution:![Screen%20Shot%202018-09-10%20at%201.54.01%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%201.54.01%20PM%20%282%29.png)

# %% [markdown]
# ## Why Probability distribution is important?
# - if we know the PD that governs a process(model) we can make prediction about that process(model)

# %% [markdown]
# # Some important statistics:
#
# ## Expected Values
# ![Screen%20Shot%202018-09-10%20at%204.42.00%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.42.00%20PM%20%282%29.png)
#
# ## Variance
#
# ![Screen%20Shot%202018-09-10%20at%204.48.02%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.48.02%20PM%20%282%29.png)

# %% [markdown]
# ## Sample Mean and Variance
# ![Screen%20Shot%202018-09-10%20at%204.50.39%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.50.39%20PM%20%282%29.png)

# %% [markdown]
# # Normal (Gaussian) Distribution
# ![Screen%20Shot%202018-09-10%20at%204.53.59%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.53.59%20PM%20%282%29.png)

# %% [markdown]
# ##  So far you have mainly studied one dimensional probabilities but data are multi-dimensional. How to deal with the multi-dimensional probabilities?
# ![Screen%20Shot%202018-09-10%20at%204.57.04%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%204.57.04%20PM%20%282%29.png)

# %% [markdown]
# ## Let's Consider a Two-dimensional Normal Distribution
# ![Screen%20Shot%202018-09-10%20at%205.00.19%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%205.00.19%20PM%20%282%29.png)
#
# ![Screen%20Shot%202018-09-10%20at%205.01.01%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%205.01.01%20PM%20%282%29.png)

# %% [markdown]
# ### Vectorized form of a multi-variate (multi-dimensional) normal distribution
# ![Screen%20Shot%202018-09-10%20at%205.02.40%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%205.02.40%20PM%20%282%29.png)

# %% [markdown]
# ### Python multivariate distribution

# %%
from scipy.stats import multivariate_normal 
x = multivariate_normal(mean=[0,0], cov=[[1,0],[0,1]])
x.pdf([1,0])
# Out:
# 0.096532352630053928

# %% [markdown]
# ### Implementing MVN in Python (example)
# ![Screen%20Shot%202018-09-10%20at%205.09.09%20PM%20%282%29.png](attachment:Screen%20Shot%202018-09-10%20at%205.09.09%20PM%20%282%29.png)
